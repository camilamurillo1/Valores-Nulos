# %% [markdown]
# <a href="https://colab.research.google.com/github/camilamurillo1/Valores-Nulos/blob/main/NoNulos_Detalle_precios_y_productos_fabricados_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Detalle precios y productos fabricados 2022.csv")
df
# Out:
#      CVE_DOC         FECHA_DOC                     NOMBRE  \
# 0     F37034  05/01/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1     F37036  05/01/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 2     F37041  05/01/2022 00:00   DIEGO ARMANDO LEON DURAN
# 3     F37042  05/01/2022 00:00   DIEGO ARMANDO LEON DURAN
# 4     F37043  05/01/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# ...      ...               ...                        ...
# 1421  F39834  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838  23/12/2022 00:00         AARON NUÑO CORDOVA
#
#                           NOMBRE.1  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# ...

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE                       2
# NOMBRE.1                     0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
df["NOMBRE"] =df["NOMBRE"].fillna("Sin registro") 
df
# Out:
#      CVE_DOC         FECHA_DOC                     NOMBRE  \
# 0     F37034  05/01/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1     F37036  05/01/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 2     F37041  05/01/2022 00:00   DIEGO ARMANDO LEON DURAN
# 3     F37042  05/01/2022 00:00   DIEGO ARMANDO LEON DURAN
# 4     F37043  05/01/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# ...      ...               ...                        ...
# 1421  F39834  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837  23/12/2022 00:00  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838  23/12/2022 00:00         AARON NUÑO CORDOVA
#
#                           NOMBRE.1  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# ...

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE                       0
# NOMBRE.1                     0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
df.to_csv("Precios y productos2022.csv")
from google.colab import files   
files.download("Precios y productos2022.csv")
